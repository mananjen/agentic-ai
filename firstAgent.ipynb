# %%
# !pip install google-adk
# Out:
# Requirement already satisfied: google-adk in c:\users\manan\anaconda3\envs\adk\lib\site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (6.0.2)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (4.10.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (0.49.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.0)
# Requirement already satisfied: cryptography in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: colorama in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.6)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.11.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.4)
# Requirement already satisfied: greenlet>=1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: tzdata in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: Mako in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.2)

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\manan\anaconda3\envs\adk\lib\site-packages (1.2.1)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

print("Key loaded:", GOOGLE_API_KEY[:8] + "..." if GOOGLE_API_KEY else "No key found")
# Out:
# Key loaded: AIzaSyCp...

# %%
try:
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("Gemini api key set successfully.")
except Exception as e:
    print("Error setting Gemini api key:", e)
# Out:
# Gemini api key set successfully.

# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("Imports successful.")
# Out:
# Imports successful.

# %%
# !pip install ipython jupyter_server --upgrade
# Out:
# Requirement already satisfied: ipython in c:\users\manan\anaconda3\envs\adk\lib\site-packages (9.7.0)
# Requirement already satisfied: jupyter_server in c:\users\manan\anaconda3\envs\adk\lib\site-packages (2.17.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from ipython) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (6.5.2)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter_server) (1.8.0)
# Requirement already satisfied: idna>=2.8 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from anyio>=3.1.0->jupyter_server) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from anyio>=3.1.0->jupyter_server) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from argon2-cffi>=21.1->jupyter_server) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jedi>=0.18.1->ipython) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jinja2>=3.0.3->jupyter_server) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-client>=7.4.4->jupyter_server) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_server) (4.5.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (4.25.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-events>=0.11.0->jupyter_server) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-events>=0.11.0->jupyter_server) (6.0.2)
# Requirement already satisfied: referencing in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-events>=0.11.0->jupyter_server) (0.37.0)
# Requirement already satisfied: rfc3339-validator in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-events>=0.11.0->jupyter_server) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jupyter-events>=0.11.0->jupyter_server) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (0.28.0)
# Requirement already satisfied: fqdn in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbconvert>=6.4.4->jupyter_server) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter_server) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbconvert>=6.4.4->jupyter_server) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbconvert>=6.4.4->jupyter_server) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbconvert>=6.4.4->jupyter_server) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbconvert>=6.4.4->jupyter_server) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbconvert>=6.4.4->jupyter_server) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter_server) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter_server) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from nbformat>=5.3.0->jupyter_server) (2.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter_server) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from stack_data>=0.6.0->ipython) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter_server) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter_server) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter_server) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\manan\anaconda3\envs\adk\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server) (2025.2)

# %%
from IPython.display import display, HTML

def get_adk_local_url(port=8000):
    url = f"http://localhost:{port}"
    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #4caf50; border-radius: 8px; background-color: #f6fff6; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>✅ ADK Web UI (Local)</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            Start the ADK server in a cell below:
            <pre><code>!adk web --port {port}</code></pre>
            Once running, click this button:
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI ↗
        </a>
    </div>
    """
    display(HTML(styled_html))
    return url

print("✅ Local helper defined.")
# Out:
# ✅ Local helper defined.

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("Agent created successfully.")
# Out:
# Agent created successfully.

# %%
runner = InMemoryRunner(agent=root_agent)

print("Runner initialized successfully.")
# Out:
# Runner initialized successfully.

# %%
response = await runner.run_debug("What is Agent Development Kit from Google? What languages is the SDK available in?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Google Agent Development Kit (ADK) is an open-source, flexible, and modular framework designed to simplify the creation, deployment, and orchestration of AI agents and multi-agent systems. It aims to make agent development feel more like traditional software development, offering developers greater control and flexibility.
#
# The ADK is optimized for the Google ecosystem, particularly for Gemini models and Vertex AI, but it is model-agnostic and deployment-agnostic, allowing compatibility with other frameworks. It supports building complex agentic applications with features like modular multi-agent architectures, a rich tool ecosystem, flexible orchestration, and built-in evaluation. Additionally, it offers features such as code-first development, allowing logic to be defined directly in code, robust debugging capabilities, and a development UI for testing and visualization.
#
# The Agent Development Kit (ADK) SDK is available in the following programming languages:
# *   **Python**
# *   **Java**
# *   **Go**

# %%
response = await runner.run_debug("What's the weather in Pilsen area of Chicago today?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in Pilsen area of Chicago today?
# helpful_assistant > The weather in the Pilsen area of Chicago today, Sunday, November 9, 2025, is expected to be cold with chances of snow and blustery conditions.
#
# Currently, it is light snow with temperatures around 29°F (-2°C), feeling like 19°F (-7°C) with about 70% humidity. There's a 55% chance of snow today. The forecast for today includes snow during the day and a heavy snow storm at night, with temperatures ranging between 28°F and 34°F (-2°C to 1°C).
#
# Later this evening and overnight, snow accumulation of 8 to 12 inches is possible, with winds at 15 to 20 mph, gusting up to 30 mph. Tomorrow, Monday, November 10, 2025, the forecast indicates light snow during the day and cloudy conditions at night, with temperatures between 27°F and 34°F (-3°C to 1°C).

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in d:\University of Illinois Chicago\agentic-ai\sample-agent:
# - .env
# - __init__.py
# - agent.py

# %%
url_prefix = get_adk_local_url(port=8000)
# Out:
#     <div style="padding: 15px; border: 2px solid #4caf50; border-radius: 8px; background-color: #f6fff6; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>✅ ADK Web UI (Local)</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             Start the ADK server in a cell below:
#             <pre><code>!adk web --port 8000</code></pre>
#             Once running, click this button:
#         </div>
#         <a href='http://localhost:8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI ↗
#         </a>
#     </div>

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# ^C
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     127.0.0.1:1753 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:1753 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1753 - "POST /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1754 - "GET /builder/app/sample-agent?ts=1762752584116 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1754 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1753 - "GET /apps/sample-agent/users/user/sessions/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1753 - "GET /debug/trace/session/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1753 - "GET /apps/sample-agent/eval_sets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1754 - "GET /apps/sample-agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1754 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1766 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1766 - "GET /apps/sample-agent/users/user/sessions/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1768 - "GET /debug/trace/session/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:1768 - "GET /debug/trace/session/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:13842 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:     127.0.0.1:13842 - "GET /apps/sample-agent/users/user/sessions/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:13844 - "GET /debug/trace/session/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:13844 - "GET /debug/trace/session/9ed43dbe-bdf0-40c8-8eb0-ea884debda60 HTTP/1.1" 200 OK
# C:\Users\Manan\anaconda3\envs\adk\Lib\site-packages\google\adk\cli\fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# C:\Users\Manan\anaconda3\envs\adk\Lib\site-packages\google\adk\auth\credential_service\in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [3980]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# 2025-11-09 23:29:44,124 - INFO - adk_web_server.py:605 - New session created: 9ed43dbe-bdf0-40c8-8eb0-ea884debda60
# 2025-11-09 23:29:58,320 - INFO - envs.py:47 - Loaded .env file for sample-agent at D:\University of Illinois Chicago\agentic-ai\sample-agent\.env
# 2025-11-09 23:29:58,320 - INFO - envs.py:47 - Loaded .env file for sample-agent at D:\University of Illinois Chicago\agentic-ai\sample-agent\.env
# 2025-11-09 23:29:58,329 - INFO - agent_loader.py:127 - Found root_agent in sample-agent.agent
# 2025-11-09 23:29:58,366 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-09 23:29:58,366 - INFO - models.py:6856 - AFC is enabled with max remote calls: 10.
# 2025-11-09 23:29:59,864 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-09 23:29:59,866 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-10 00:10:17,388 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-10 00:10:17,388 - INFO - models.py:6856 - AFC is enabled with max remote calls: 10.
# 2025-11-10 00:10:24,255 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-10 00:10:24,257 - INFO - google_llm.py:186 - Response received from the model.
