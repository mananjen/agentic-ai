# %%
import os
from dotenv import load_dotenv

load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

print("Key loaded:", GOOGLE_API_KEY[:8] + "..." if GOOGLE_API_KEY else "No key found")
# Out:
# Key loaded: AIzaSyCp...

# %%
try:
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print("❌ Error setting up Gemini API key:", str(e))
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# # Research & Summarization System

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use your knowledge and the google_search tool to find pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings} Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing is rapidly advancing and merging with AI, a synergy known as \"Quantum AI.\" This combination promises to dramatically increase computational power and revolutionize various sectors. Key developments include:
#
# *   **Faster AI and Machine Learning:** Quantum computers can significantly accelerate AI and ML algorithms, leading to faster data processing and improved optimization for tasks like resource allocation and recommendation systems.
# *   **Solving Complex Problems:** Quantum AI is expected to solve problems that are currently intractable due to computational limits, particularly in fields such as drug discovery, materials science, and climate modeling, by simulating complex interactions with unprecedented fidelity.
# *   **Hardware and Quantum Neural Network Improvements:** Progress in developing more stable and scalable quantum computers, along with breakthroughs in making quantum neural networks trainable, are paving the way for practical AI applications.
# *   **Emerging Commercial Uses and Enhanced AI:** Early commercial applications of quantum-assisted AI are emerging in industries like finance and logistics. Furthermore, quantum computing can improve generative AI outputs and data analytics by providing high-quality randomness and efficiently processing vast datasets.
# *   **Security Concerns:** The rise of quantum computing necessitates a complete revamp of digital security, as current encryption methods may become obsolete, prompting research into quantum-resistant algorithms.

# %% [markdown]
# # Blog Post Creation with Sequential Agents

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Blog Post Outline:
#
# **1. Headline:** Supercharge Your Code: How Multi-Agent Systems Are Revolutionizing Software Development
#
# **2. Introduction Hook:** Ever feel like you're juggling too many tasks, or that your software could be doing so much more? Imagine a team of intelligent, specialized "mini-programs" working tirelessly behind the scenes, automating complex processes, and enhancing your application's capabilities. That's the power of multi-agent systems (MAS), and as a software developer, understanding them is no longer optional – it's your next competitive edge.
#
# **3. Main Sections:**
#
# *   **Section 1: What Exactly Are Multi-Agent Systems (and Why Should You Care?)**
#     *   Define MAS as a collection of autonomous agents that interact to achieve a common goal or solve complex problems.
#     *   Highlight the key characteristics: autonomy, reactivity, proactivity, and social ability.
#     *   Briefly touch on how this differs from traditional monolithic software architectures.
#
# *   **Section 2: Unleashing Efficiency: How MAS Streamlines Development Workflows**
#     *   **Automated Task Management:** Agents can handle repetitive coding, testing, and deployment tasks, freeing up developers for more creative problem-solving.
#     *   **Intelligent Code Completion & Generation:** Imagine AI agents that not only suggest code but can even generate entire modules based on your specifications, learning from your coding style.
#     *   **Proactive Bug Detection & Resolution:** Agents can continuously monitor code for potential issues, identify root causes, and even suggest or implement fixes before they become major problems.
#
# *   **Section 3: Building Smarter, More Robust Software with MAS**
#     *   **Enhanced Scalability & Adaptability:** MAS can dynamically adjust their behavior and resource allocation based on system demands, making applications more resilient.
#     *   **Complex Problem Solving:** Break down intricate challenges into smaller, manageable tasks for individual agents, allowing for more elegant and efficient solutions.
#     *   **Improved User Experience:** Agents can personalize user interactions, anticipate needs, and provide more responsive and intuitive application behavior.
#
# *   **Section 4 (Optional): Getting Started with Multi-Agent Systems**
#     *   Briefly mention popular MAS frameworks and libraries (e.g., JADE, SPADE, AgentPy).
#     *   Suggest starting with small, well-defined use cases to gain practical experience.
#     *   Emphasize the importance of understanding agent communication protocols and coordination strategies.
#
# **4. Concluding Thought:** Multi-agent systems are more than just a theoretical concept; they are a tangible pathway to building more intelligent, efficient, and adaptable software. By embracing this paradigm, you're not just writing code, you're orchestrating a symphony of intelligent agents that can elevate your development process and the solutions you deliver to the world. The future of software development is collaborative, and MAS are leading the charge.
# WriterAgent > ## Supercharge Your Code: How Multi-Agent Systems Are Revolutionizing Software Development
#
# Ever feel like you're juggling too many tasks, or that your software could be doing so much more? Imagine a team of intelligent, specialized "mini-programs" working tirelessly behind the scenes, automating complex processes, and enhancing your application's capabilities. That's the power of multi-agent systems (MAS), and as a software developer, understanding them is no longer optional – it's your next competitive edge.
#
# At its core, a multi-agent system is a collection of autonomous agents, each with its own goals and behaviors, that interact to achieve a common objective or solve complex problems. Unlike traditional monolithic architectures, MAS brings autonomy, reactivity, proactivity, and social ability to your software development.
#
# This paradigm shift unlocks incredible efficiency. MAS can automate repetitive coding, testing, and deployment tasks, freeing you for more creative work. Picture AI agents that offer intelligent code completion, generate entire modules based on your specs, or proactively detect and even resolve bugs before they escalate.
#
# Beyond development workflows, MAS allows you to build smarter, more robust software. These systems offer enhanced scalability and adaptability, dynamically adjusting to system demands. They excel at tackling intricate problems by breaking them down for individual agents, leading to more elegant solutions. Ultimately, this translates to improved user experiences, with applications that can personalize interactions and anticipate user needs.
#
# Embracing MAS means you're not just writing code; you're orchestrating a symphony of intelligent agents. This collaborative approach is elevating development and the solutions we deliver. The future of software is intelligent and adaptable, and multi-agent systems are leading the charge.
# EditorAgent > ## Supercharge Your Code: How Multi-Agent Systems Are Revolutionizing Software Development
#
# Do you ever feel overwhelmed by your workload, wishing your software could handle more complex tasks or operate with greater intelligence? Imagine having a team of specialized, autonomous "mini-programs" working seamlessly behind the scenes. These agents could automate intricate processes, enhance your application's capabilities, and tackle challenges with unprecedented efficiency. This is the promise of multi-agent systems (MAS), and for software developers, understanding them is rapidly becoming essential for staying ahead.
#
# At its heart, a multi-agent system comprises a collection of independent agents, each possessing its own goals and behaviors. These agents collaborate and interact to achieve a shared objective or solve complex problems. This contrasts sharply with traditional monolithic software architectures. MAS introduces crucial characteristics like **autonomy** (agents acting independently), **reactivity** (responding to their environment), **proactivity** (taking initiative), and **social ability** (interacting with other agents).
#
# This paradigm shift unlocks remarkable efficiency gains in development. MAS can automate time-consuming, repetitive tasks such as coding, testing, and deployment. This frees developers to focus on more creative and strategic aspects of software design. Consider AI agents capable of offering intelligent code suggestions, generating entire code modules based on your specifications, or even proactively identifying and resolving bugs before they impact users.
#
# Beyond streamlining development workflows, MAS empowers you to build smarter, more resilient software. These systems offer superior scalability and adaptability, dynamically adjusting their resource allocation and behavior in response to changing system demands. They excel at dissecting and solving intricate problems by distributing tasks among individual agents, leading to more elegant and efficient solutions. Ultimately, this translates into enhanced user experiences, with applications that can offer personalized interactions and intelligently anticipate user needs.
#
# Adopting multi-agent systems means you're moving beyond simply writing code. You're becoming an orchestrator, guiding a symphony of intelligent agents. This collaborative approach is fundamentally elevating how we develop software and the sophisticated solutions we deliver. The future of software development is intelligent, adaptable, and collaborative, with multi-agent systems paving the way.

# %% [markdown]
# # Parallel Multi-Topic Research

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **Tech:** AI continues its rapid integration, with **Generative AI** and **Agentic AI** leading the charge. Companies like **OpenAI**, **Google**, and **Microsoft** are heavily involved in developing advanced AI models and platforms. The impact includes hyper-personalized experiences, accelerated software development, and new forms of human-machine collaboration.
#
# **Health:** The wellness sector is focusing on **personalized health** through AI and wearables, **functional nutrition**, and **preventive wellness**. Key players include companies developing AI-driven health apps and diagnostic tools. This trend aims to optimize healthspan and offer tailored approaches to individual well-being.
#
# **Finance:** **Generative AI** is transforming financial services by enhancing customer experience and developing new wealth management tools. Additionally, trends like **open banking** and a rebound in **M&A and IPO activity** are shaping the sector. Major financial institutions and tech providers like **IBM** are integrating these advancements. The impact is a more customer-centric, efficient, and interconnected financial ecosystem.
# HealthResearcher > Here's your executive briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** AI is revolutionizing diagnostics and treatment plans, with AI-driven sepsis detection showing a 20% decrease in related deaths in trials. mRNA vaccine technology, proven with COVID-19 vaccines, is now being explored for numerous other diseases. Advancements in gene sequencing enable faster identification of dangerous mutations.
# *   **Practical Applications:** Improved disease detection, personalized medicine, rapid vaccine development.
# *   **Estimated Timeline:** Ongoing development, with widespread clinical adoption expected within 5-10 years.
#
# **Tech:** Artificial Intelligence (AI) continues its rapid advancement, particularly in generative AI, impacting content creation and automation across sectors. Quantum computing is progressing, with significant investment and research focused on practical applications in areas like cryptography and material science, though widespread adoption is still debated. The Internet of Things (IoT) is expanding, integrating more devices for automation and control in industries and homes.
# *   **Practical Applications:** Enhanced automation, advanced data analysis, new cybersecurity solutions, improved industrial efficiency.
# *   **Estimated Timeline:** AI and IoT are seeing immediate integration, while practical quantum computing applications are estimated within the next 10-20 years.
#
# **Finance:** AI and machine learning are reshaping financial services through personalized advice, fraud detection, and risk assessment. Digital assets and distributed ledger technologies are creating new payment and settlement infrastructures, raising questions about interoperability and regulation. Central banks are exploring digital currencies.
# *   **Practical Applications:** Smarter financial advisors, more secure transactions, potential for new digital currencies, improved risk management.
# *   **Estimated Timeline:** Ongoing integration, with significant shifts in payment systems and digital currency adoption anticipated within the next 5-15 years.
# FinanceResearcher > Here's your daily executive briefing for November 10, 2025:
#
# **Technology:**
# *   **Space-Based Data Centers:** Tech giants are exploring orbital data centers to meet soaring AI energy demands, with initial tests underway and commercial viability projected within a decade.
# *   **AI Partnerships:** Apple has reportedly struck a $1 billion annual deal with Google to leverage Gemini models for its AI upgrades, while maintaining user data privacy through its own cloud servers.
# *   **Cloud Infrastructure:** AWS and OpenAI have formalized a seven-year, $38 billion partnership for advanced AI workloads, securing significant GPU and CPU resources for OpenAI.
#
# **Health:**
# *   **Hormone Replacement Therapy (HRT):** The FDA is initiating the removal of broad "black box" warnings from HRT products for menopause, based on updated scientific reviews, aiming to provide women with more informed treatment options.
# *   **Measles Reemergence:** Endemic measles transmission has been reestablished in Canada, highlighting the risk of reintroduction and spread in the Americas without sustained vaccination efforts.
# *   **Health System Consolidation:** Mergers in the health sector are contributing to rising patient costs, with ongoing debate about potential regulatory intervention.
#
# **Finance:**
# *   **Financial Services Conferences:** Key players like JPMorgan Chase and BNY Mellon are scheduled to present at upcoming Goldman Sachs Financial Services Conferences, offering insights into their strategies and market outlooks.
# *   **Regulatory Updates:** The EU is postponing the application of disclosure requirements for certain undertakings, while the U.S. Treasury is launching a broad investigation into potential fraud across its contracting programs.
# *   **Market Sentiment:** Strategists suggest the stock market is due for a reset as investors reassess risk, particularly concerning the dominance of tech stocks.
#
# **Key Fintech Trends:**
#
# 1.  **AI Integration in Financial Services:** AI is revolutionizing customer service, fraud detection, and personalized financial advice. Market implication: Increased efficiency, improved customer experience, and new revenue streams. Future outlook: Deeper AI integration, hyper-personalization, and autonomous financial agents.
# 2.  **Embedded Finance:** Financial services are increasingly being integrated into non-financial platforms (e.g., e-commerce, social media). Market implication: Seamless user experiences, expanded customer reach for financial providers, and new distribution channels. Future outlook: Ubiquitous financial services, "super apps," and "finance-as-a-service" models.
# 3.  **Decentralized Finance (DeFi) Evolution:** While volatile, DeFi continues to innovate in areas like stablecoins, lending, and insurance, with a growing focus on regulatory compliance and institutional adoption. Market implication: Increased competition for traditional finance, greater financial inclusion, and new asset classes. Future outlook: Maturing DeFi protocols, bridges between DeFi and TradFi, and regulated decentralized ecosystems.
# AggregatorAgent > ## Executive Summary: AI-Driven Transformation Across Tech, Health, and Finance
#
# **The pervasive influence of Artificial Intelligence (AI) is the most significant unifying theme across technology, health, and finance.** Generative and agentic AI are rapidly advancing, leading to hyper-personalized experiences, accelerated development, and new forms of collaboration. In technology, this manifests in massive AI infrastructure partnerships and exploration of even space-based data centers.
#
# **AI's impact on health is profound, driving personalized wellness, improved diagnostics (e.g., AI-driven sepsis detection), and rapid vaccine development through technologies like mRNA.** This pursuit of optimized healthspan and tailored approaches is key.
#
# **Finance is being revolutionized by AI for enhanced customer experience, fraud detection, and wealth management.** Coupled with trends like open banking and the evolution of digital assets and DeFi, AI is fostering a more interconnected, efficient, and customer-centric financial ecosystem. While quantum computing and IoT are also expanding, AI's immediate and transformative impact across all sectors is undeniable, promising significant shifts within the next 5-15 years.

# %% [markdown]
# # Iterative Story Refinement

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias polished the brass railing, the salty air a familiar embrace. For twenty years, the lighthouse had been his world, a solitary sentinel against the unforgiving sea. Tonight, however, felt different. A storm brewed on the horizon, but it was a flicker from the rocky shore below that truly captured his attention.
#
# He descended the spiral stairs, his lantern casting dancing shadows. Nestled amongst seaweed and driftwood was a rolled-up parchment, impossibly dry. Unfurling it, Elias gasped. The map wasn't drawn with ink, but with a bioluminescent substance that pulsed with an ethereal blue light. Strange, swirling symbols adorned it, depicting not coastlines, but constellations he’d never seen, and a single, bold X marked a place far beyond known waters.
# CriticAgent > This is a strong start to a story, with intriguing elements that immediately pique the reader's interest.
#
# Here are a few suggestions for improvement:
#
# *   **Deepen Elias's character:** While we know he's been a lighthouse keeper for twenty years, giving Elias a brief internal thought or feeling about his isolation or his longing for something more would make him more relatable and the discovery of the map more impactful. For instance, does he feel a sense of duty, resignation, or quiet contentment in his solitude?
# *   **Enhance the discovery moment:** The description of the map is excellent, but consider adding a sensory detail beyond the visual. Does the parchment have a strange texture? Is there a faint scent associated with it? This can further heighten the mystery and strangeness of the object.
# *   **Hint at the map's implications:** The map points "far beyond known waters." Briefly alluding to what this might mean for Elias, or what his reaction to such a prospect is, can add immediate stakes and foreshadow future conflict or adventure. Is he fearful, excited, or bewildered by the implication of such a journey?
# RefinerAgent > Elias polished the brass railing, the salty air a familiar embrace. For twenty years, the lighthouse had been his world, a solitary sentinel against the unforgiving sea. His days were a quiet rhythm of maintaining the light, his nights filled with the endless murmur of the waves. Sometimes, a deep ache of loneliness settled in his chest, a longing for a life beyond the horizon. Tonight, however, felt different. A storm brewed, a familiar adversary, but it was a strange flicker from the rocky shore below that truly captured his attention, a pulsing light that defied the natural world.
#
# He descended the spiral stairs, his lantern casting dancing shadows that seemed to mock his solitary existence. Nestled amongst the kelp and driftwood was a rolled-up parchment, impossibly dry, its surface smooth and cool to the touch, unlike any paper he’d ever encountered. Unfurling it, Elias gasped. The map wasn't drawn with ink, but with a bioluminescent substance that pulsed with an ethereal blue light, smelling faintly of ozone and something ancient, like starlight captured in a bottle. Strange, swirling symbols adorned it, depicting not coastlines, but constellations he’d never seen, alien star-patterns that hinted at cosmic journeys. A single, bold X marked a place far beyond known waters, a destination that sent a shiver of both fear and exhilarating possibility down his spine. This was not just a map; it was a siren's call, an invitation to a destiny he'd only ever dreamed of in his loneliest hours.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
